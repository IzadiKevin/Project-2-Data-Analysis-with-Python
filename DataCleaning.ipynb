# %% [markdown]
# ### Author: Kevin Izadi
# ### Date Created: 10/17/2022
# ### Class: Data Science Programming

# %% [markdown]
# ### Data Cleaning on the 2020 Computing Entry survey 2020 and the Computer Literary Survey 2020
# ## What I believe should be edited:
# #### The problem I notice is that certain columns are more unique than the other and some are specifically redundant to the quesiton it's asking.

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\izadi\Desktop\Data Science Programming\CCM Computing Entry Survey - Fall 2020.csv')
df2 = pd.read_csv(r'C:\Users\izadi\Desktop\Data Science Programming\CCM Computing Literacy Course Entry Survey - Fall 2020.csv')

# %% [markdown]
# #### ^This is to read each csv file and register them by df(Computing Entry survey) and df2(Literacy course entry survey)

# %% [markdown]
# ## *What are the best methods for reaching out to students? How did most students hear about a computing class?
#
# #### This question can be tackled based on visualizing the data, In the Computing Entry survey, the best methods for reaching out to students was the CCM admissions that most of the survey responders put "Yes" on. So using that method, I believe the best method to reach out to students would be to make the Computer science course more applicable towards other sets of majors.

# %% [markdown]
# ## *What can you learn from the non-majors taking the computing entry-level classes (CMP 128, 120, 239, etc)
#
# #### What I've noticed from the non-majors taking computing entry level courses was that participants would ratherly say that either the course is a part of their CSI elective(IT majors) and the other majors wouldn't respond at all on their feedback from the courses. For example, almost all if not all of the people who put "Undecided" as their major left the row blank for their feedback on how did they hear about CCM computing programs.

# %%
df['What degree program are you currently enrolled in?'].value_counts().plot(kind="bar", figsize=(15,7), color="#61d199")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What I notice from this is that there are more IT students taking Computer Science entry classes than Computer Science majors themselves.

# %% [markdown]
# ## *What can you learn from the students in the computer literacy courses and what interests they may or may not have in computing?
#
# #### What I learned from the students in the computer literacy courses is that a vast variety of them are in a diverse amount of computer courses and a large varity of students who take different majors taking computer science classes.
# #### I learned through the csv file that the students interest are that it's very peculier. Certain Students choose to pick the course through usually a elective requirement or sheer enjoyment instead.

# %% [markdown]
# ## *What is the average Age group of students who take Computer Science?

# %%
df['Age '].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What I notice is that it's a left skewed graph depicting the age groups who take Computer Science. The highest being 18 and younger are the ones taking Computer science. I believe that making the Computer Science courses entirely more appealing for all ages should be a notice.
# #### and another interesting thing was the amount of people older than 35 at CCM taking computer science courses
